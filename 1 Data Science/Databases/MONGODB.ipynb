# %%
# pip install pymongo[srv]
# pip install pymongo
import pymongo
client = pymongo.MongoClient("mongodb+srv://sakethchoudary227:Skqgi9782@cluster0.v079hz2.mongodb.net/?retryWrites=true&w=majority")
db = client.test
print(db,end='\n\n')

d = {
    "name": "saketh",
     "email": "sakethchoudary227@gmail.com",
     "surname": "linga"
}


db1 = client['mongotest'] # database name
coll = db1['test'] # table name
coll.insert_one(d) # document to be inserted

list_of_records = [
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Machine Learning with Deployment'},

    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Deep Learning for NLP and Computer vision'},

    {'companyName': 'iNeuron',
     'product': 'Master Program',
     'courseOffered': 'Data Science Masters Program'}
]
coll=db1['info']
coll.insert_many(list_of_records)

record = coll.find()
for i in record:
    print(i,end='\n\n')
# Out:
# Database(MongoClient(host=['ac-g8i4en7-shard-00-02.v079hz2.mongodb.net:27017', 'ac-g8i4en7-shard-00-00.v079hz2.mongodb.net:27017', 'ac-g8i4en7-shard-00-01.v079hz2.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-f6kwpf-shard-0', tls=True), 'test')
#
# {'_id': ObjectId('63268b7fecf638b34427bd49'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
#
# {'_id': ObjectId('63268b7fecf638b34427bd4a'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# {'_id': ObjectId('63268b7fecf638b34427bd4b'), 'companyName': 'iNeuron', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}

# %%
database= client['mongotest']
collection=database['info']

for i in collection.find():
    print(i,end='\n\n')

print('============================================================================================================')

for i in collection.find({'product': 'Affordable AI'}):
    print(i,end='\n\n')

print('============================================================================================================')

for i in collection.find({'courseOffered':{'$gte':'M'}}):
    print(i,end='\n\n')

print('============================================================================================================')

for i in collection.find({'courseOffered':{'$gt':'N'}}):
    print(i,end='\n\n')
# Out:
# {'_id': ObjectId('63268b7fecf638b34427bd49'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
#
# {'_id': ObjectId('63268b7fecf638b34427bd4a'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# {'_id': ObjectId('63268b7fecf638b34427bd4b'), 'companyName': 'iNeuron', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
#
# ...
# {'_id': ObjectId('63268b7fecf638b34427bd49'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
#
# {'_id': ObjectId('63268b7fecf638b34427bd4a'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
#
# ...
# {'_id': ObjectId('63268b7fecf638b34427bd49'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
#
# ...

# %%
database= client['mongotest']
collection=database['sample1']

data =  [
        {
            "item": "canvas",
            "qty": 100,
            "size": {"h": 28, "w": 35.5, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "journal",
            "qty": 25,
            "size": {"h": 14, "w": 21, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "mat",
            "qty": 85,
            "size": {"h": 27.9, "w": 35.5, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "mousepad",
            "qty": 25,
            "size": {"h": 19, "w": 22.85, "uom": "cm"},
            "status": "P",
        },
        {
            "item": "notebook",
            "qty": 50,
            "size": {"h": 8.5, "w": 11, "uom": "in"},
            "status": "P",
        },
        {
            "item": "paper",
            "qty": 100,
            "size": {"h": 8.5, "w": 11, "uom": "in"},
            "status": "D",
        },
        {
            "item": "planner",
            "qty": 75,
            "size": {"h": 22.85, "w": 30, "uom": "cm"},
            "status": "D",
        },
        {
            "item": "postcard",
            "qty": 45,
            "size": {"h": 10, "w": 15.25, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "sketchbook",
            "qty": 80,
            "size": {"h": 14, "w": 21, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "sketch pad",
            "qty": 95,
            "size": {"h": 22.85, "w": 30.5, "uom": "cm"},
            "status": "A",
        },
    ]

collection.insert_many(data)

# %%
for i in collection.find():
    print(i,end='\n\n')
# Out:
# {'_id': ObjectId('63268dafecf638b34427bd4c'), 'item': 'canvas', 'qty': 100, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
#
# {'_id': ObjectId('63268dafecf638b34427bd4d'), 'item': 'journal', 'qty': 25, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
#
# {'_id': ObjectId('63268dafecf638b34427bd4e'), 'item': 'mat', 'qty': 85, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
#
# {'_id': ObjectId('63268dafecf638b34427bd4f'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
#
# {'_id': ObjectId('63268dafecf638b34427bd50'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
#
# {'_id': ObjectId('63268dafecf638b34427bd51'), 'item': 'paper', 'qty': 100, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
#
# {'_id': ObjectId('63268dafecf638b34427bd52'), 'item': 'planner', 'qty': 75, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
#
# ...

# %%
for i in collection.find({'status':'A'}):
    print(i)

print('==========================================================================================================')

for i in collection.find({'status':{'$in':['A','P']}}):
    print(i)

print('==========================================================================================================')

for i in collection.find({'status':{'$gt':'E'}}):
    print(i)

print('==========================================================================================================')

for i in collection.find({'qty':100}):
    print(i)

print('==========================================================================================================')

for i in collection.find({'qty':{'$gte':75}}):
    print(i)

print('==========================================================================================================')

for i in collection.find({'item': 'sketch pad','qty':{"$gt":90}}):
    print(i)

print('==========================================================================================================')






# or condition
for i in collection.find({'$or':[{'item': 'sketch pad'},{'qty':{"$gt":90}}]}):
    print(i)

print('==========================================================================================================')
 # updation
collection.update_one({'item': 'canvas'},{'$set':{'item':'Saketh'}})
for i in collection.find({'item': 'Saketh'}):
    print(i)
# Deletion
collection.delete_one({'item': 'Saketh'})
# Out:
# {'_id': ObjectId('63268dafecf638b34427bd4d'), 'item': 'journal', 'qty': 25, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('63268dafecf638b34427bd4e'), 'item': 'mat', 'qty': 85, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('63268dafecf638b34427bd53'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('63268dafecf638b34427bd54'), 'item': 'sketchbook', 'qty': 80, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('63268dafecf638b34427bd55'), 'item': 'sketch pad', 'qty': 95, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
# ...
# {'_id': ObjectId('63268dafecf638b34427bd4d'), 'item': 'journal', 'qty': 25, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('63268dafecf638b34427bd4e'), 'item': 'mat', 'qty': 85, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# ...
