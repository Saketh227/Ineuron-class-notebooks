# %%
import pandas as pd

attr_data=pd.read_excel(r"D:\Full stack Data  Science by INEURON\datasets\dataset\Attribute Dataset.xlsx") # use r or\\(double back slash) when you face unicode error
print(type(attr_data))

attr_data.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
attr_data.dtypes
# Out:
# Dress_ID            int64
# Style              object
# Price              object
# Rating            float64
# Size               object
# Season             object
# NeckLine           object
# SleeveLength       object
# waiseline          object
# Material           object
# FabricType         object
# Decoration         object
# Pattern Type       object
# Recommendation      int64
# dtype: object

# %% [markdown]
# # Arguments
# > **`sheet_name`**:  `'str | int | list[IntStrT] | None(all sheets)' = 0(default),`
#
# >**`header`**: `'int | Sequence[int] | None' = 0,`
#
# >**`names`**
#
# >**`sep`**

# %%
# argument `sheetname` how to use this

'''one excel file can contain many sheets 
    so specify sheet name otherwise the first sheet is chosen
    
    Sheet name can be string or 
                      int(starts from 0) or 
                      list of integers/str(it gives dict of all the dataframes with integers(start from 0) as keys)'''


attr_data1=pd.read_excel(r"D:\Full stack Data  Science by INEURON\datasets\dataset\Attribute Dataset.xlsx",sheet_name='Sheet2') # sheet_name=1
attr_data1
# Out:
#   Unnamed: 0 Unnamed: 1
# 0        NaN        NaT
# 1        NaN        NaT
# 2     Saketh 1998-10-09
# 3    Saisree 1995-04-27
# 4     mahima 1996-08-15

# %%
attr_data1=pd.read_excel(r"D:\Full stack Data  Science by INEURON\datasets\dataset\Attribute Dataset.xlsx",sheet_name=[0,1])
print(type(attr_data1))

print(attr_data1[0].head())

print("====================================================================================")

print(attr_data1[1].head())
# Out:
# <class 'dict'>
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0
# ...
#   Unnamed: 0 Unnamed: 1
# ...

# %%
# header argument

# header=None
attr_data1=pd.read_excel(r"D:\Full stack Data  Science by INEURON\datasets\dataset\Attribute Dataset.xlsx",
                         sheet_name='Sheet2',header=None)
print("the actual data is :\n",attr_data1.head())
print("====================================================================================")


# header argument is not mentioned and it takes default value i.e 0 
attr_data1=pd.read_excel(r"D:\Full stack Data  Science by INEURON\datasets\dataset\Attribute Dataset.xlsx",
                         sheet_name='Sheet2')
print("the data when header=0 is :\n",attr_data1.head())
print("====================================================================================")


# header = 3
attr_data1=pd.read_excel(r"D:\Full stack Data  Science by INEURON\datasets\dataset\Attribute Dataset.xlsx",
                         sheet_name='Sheet2',header=3)

print("the data when header=3 is :\n",attr_data1.head())
# Out:
# the actual data is :
#           0          1
# 0      NaN        NaT
# 1      NaN        NaT
# 2      NaN        NaT
# 3   Saketh 1998-10-09
# 4  Saisree 1995-04-27
# ...
# the data when header=0 is :
#    Unnamed: 0 Unnamed: 1
# 0        NaN        NaT
# 1        NaN        NaT
# 2     Saketh 1998-10-09
# 3    Saisree 1995-04-27
# 4     mahima 1996-08-15
# ...
# the data when header=3 is :
#      Saketh 1998-10-09 00:00:00
# 0  Saisree          1995-04-27
# 1   mahima          1996-08-15

# %%
# names argument
'''It replaces the header row values with values given in argument'''
attr_data1=pd.read_excel(r"D:\Full stack Data  Science by INEURON\datasets\dataset\Attribute Dataset.xlsx",
                         sheet_name='Sheet2',header=None,names=['name','dob'])
print(attr_data1)
print("=========================================================================================================")


attr_data1=pd.read_excel(r"D:\Full stack Data  Science by INEURON\datasets\dataset\Attribute Dataset.xlsx",
                         sheet_name='Sheet2',names=['name','dob'])
print(attr_data1)
# Out:
#       name        dob
# 0      NaN        NaT
# 1      NaN        NaT
# 2      NaN        NaT
# 3   Saketh 1998-10-09
# 4  Saisree 1995-04-27
# 5   mahima 1996-08-15
# ...
#       name        dob
# 0      NaN        NaT
# 1      NaN        NaT
# 2   Saketh 1998-10-09
# 3  Saisree 1995-04-27
# 4   mahima 1996-08-15

# %%
# sep argument

# Before using sep argument
attr_data1=pd.read_csv(r"D:\Full stack Data  Science by INEURON\datasets\dataset\haberman1.csv",
                       header=None,names=[ 'Age of patient at time of operation',"Patient's year of operation",
                                          "Number of positive axillary nodes detected","Survival status"])
print("Before using sep argument, the data is: \n",attr_data1.head(4))

print("===================================================================================================")

attr_data1=pd.read_csv(r"D:\Full stack Data  Science by INEURON\datasets\dataset\haberman1.csv",
                       header=None,
                       names=[ 'Age of patient at time of operation',
                                          "Patient's year of operation",
                                          "Number of positive axillary nodes detected",
                                          "Survival status"],
                      sep='@')
print("After using sep argument, the data is: \n",attr_data1.head(4))
# Out:
# Before using sep argument, the data is:
#    Age of patient at time of operation  Patient's year of operation  \
# 0                           30@64@1@1                          NaN
# 1                           30@62@3@1                          NaN
# 2                           30@65@0@1                          NaN
# 3                           31@59@2@1                          NaN
#
#    Number of positive axillary nodes detected  Survival status
# 0                                         NaN              NaN
# 1                                         NaN              NaN
# 2                                         NaN              NaN
# 3                                         NaN              NaN
# ...
# After using sep argument, the data is:
#     Age of patient at time of operation  Patient's year of operation  \
# 0                                   30                           64
# 1                                   30                           62
# ...

# %%
# index_col argument
'''If there is a column in data that contain indexes we need to used this argument
   default value is None'''
attr_data1=pd.read_excel(r"D:\Full stack Data  Science by INEURON\datasets\dataset\Attribute Dataset.xlsx",
                         sheet_name='Sheet3')
print(attr_data1.head(2))
print("=================================================================================")

attr_data1=pd.read_excel(r"D:\Full stack Data  Science by INEURON\datasets\dataset\Attribute Dataset.xlsx",
                         sheet_name='Sheet3',index_col=0)
attr_data1.head(2)
# Out:
#    Unnamed: 0    name  age  salary
# 0           0  saketh   23   10000
# 1           1  saketh   43   24000
# ...
#      name  age  salary
# 0  saketh   23   10000
# 1  saketh   43   24000

# %% [markdown]
# **`csv to json`**
# **`csv to csv`**

# %%
attr_data1=pd.read_excel(r"D:\Full stack Data  Science by INEURON\datasets\dataset\Attribute Dataset.xlsx",
                         sheet_name='Sheet3',index_col=0)
print(attr_data1.head(2))

attr_data1.to_json('test.json')
# Out:
#      name  age  salary
# 0  saketh   23   10000
# 1  saketh   43   24000

# %% [markdown]
# # Miscillaneous
# * how to read csv from github directly
# * how to read tables from a website

# %%
import pandas as pd
data=pd.read_csv('D:\Full stack Data  Science by INEURON\datasets\dataset\superstore_sales_new.csv',encoding='latin1')
data.head(4)
# Out:
#           order_id  order_date   ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040  01-01-2011  01-06-2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883  01-01-2011  01-08-2011  Standard Class      Joseph Holt
# 2     HU-2011-1220  01-01-2011  01-05-2011    Second Class    Annie Thurman
# 3  IT-2011-3647632  01-01-2011  01-05-2011    Second Class     Eugene Moren
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
#
#           category sub_category                 product_name sales quantity  \
# 0  Office Supplies      Storage          Tenex Lockers, Blue   408        2
# 1  Office Supplies     Supplies     Acme Trimmer, High Speed   120        3
# ...

# %% [markdown]
# # Methods

# %%
# methods
print(data.columns, end="\n\n")
print("=====================================", end="\n\n")      
print(data.dtypes, end="\n\n")
print("=====================================", end="\n\n") 


print(data.describe(), end="\n\n")
print("=====================================", end="\n\n") 
print(data[['ship_mode','segment', 'state', 'country', 'market', 'region']].describe(), end="\n\n")

print("=====================================", end="\n\n") 
print(data.index, end="\n\n")
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')
#
# ...
#
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object
#
# ...
#
# ...

# %%
print(type(data['market'].isnull()), end="\n\n")
print(data['market'].isnull().head(), end="\n\n")
print("=====================================", end="\n\n")

print(data[['segment','ship_mode']].value_counts(), end="\n\n")
print(data['ship_mode'].value_counts(), end="\n\n")
print("=====================================", end="\n\n")
# Out:
# <class 'pandas.core.series.Series'>
#
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: market, dtype: bool
#
# ...
#
# segment      ship_mode
# Consumer     Standard Class    15876
# Corporate    Standard Class     9258
# Home Office  Standard Class     5641
# Consumer     Second Class       5257
#              First Class        3918
# Corporate    Second Class       3198
#              First Class        2245
# Home Office  Second Class       1854
# Consumer     Same Day           1467
# Home Office  First Class        1342
# Corporate    Same Day            728
# Home Office  Same Day            506
# dtype: int64
#
# Standard Class    30775
# Second Class      10309
# First Class        7505
# Same Day           2701
# Name: ship_mode, dtype: int64
#
# ...

# %% [markdown]
# # Accessing

# %%
# Accessing
print(data['customer_name'][:5], end="\n\n")
print(type(data['order_date']), end="\n\n")
print('===============================================')


print(type(data[['order_date']][:5]), end="\n\n")
print(data[['order_date']], end="\n\n") # this is dataframe

print('===============================================')

data[['order_date','profit']][:10:2]
# Out:
# 0    Toby Braunhardt
# 1        Joseph Holt
# 2      Annie Thurman
# 3       Eugene Moren
# 4        Joseph Holt
# Name: customer_name, dtype: object
#
# <class 'pandas.core.series.Series'>
#
# ...
# <class 'pandas.core.frame.DataFrame'>
#
#        order_date
# 0      01-01-2011
# 1      01-01-2011
# 2      01-01-2011
# 3      01-01-2011
# 4      01-01-2011
# ...           ...
# 51285  12/31/2014
# 51286  12/31/2014
# 51287  12/31/2014
# 51288  12/31/2014
# 51289  12/31/2014
#
# [51290 rows x 1 columns]
#
# ...
#    order_date   profit
# 0  01-01-2011  106.140
# 2  01-01-2011   29.640
# 4  01-01-2011   37.770
# 6  01-02-2011    3.120
# 8  01-03-2011 -319.464

# %%
data.iloc

# %% [markdown]
# # Filtering Operations

# %%
# How to filter columns based on its datatype

print(type(data.dtypes))
data[data.dtypes[data.dtypes=='object'].index].head()
# Out:
# <class 'pandas.core.series.Series'>
#           order_id  order_date   ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040  01-01-2011  01-06-2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883  01-01-2011  01-08-2011  Standard Class      Joseph Holt
# 2     HU-2011-1220  01-01-2011  01-05-2011    Second Class    Annie Thurman
# 3  IT-2011-3647632  01-01-2011  01-05-2011    Second Class     Eugene Moren
# 4    IN-2011-47883  01-01-2011  01-08-2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region        product_id  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  OFF-TEN-10000025
# 1     Consumer  New South Wales  Australia    APAC  Oceania   OFF-SU-10000618
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  OFF-TEN-10001585
# 3  Home Office        Stockholm     Sweden      EU    North   OFF-PA-10001492
# 4     Consumer  New South Wales  Australia    APAC  Oceania   FUR-FU-10003447
#
# ...

# %%
data[data['profit']==max(data['profit'])
# Out:
#              order_id  order_date   ship_date       ship_mode customer_name  \
# 29530  CA-2013-118689  10-03-2013  10-10-2013  Standard Class  Tamara Chand
#
#          segment    state        country market   region  ...    category  \
# 29530  Corporate  Indiana  United States     US  Central  ...  Technology
#
#       sub_category                           product_name   sales quantity  \
# 29530      Copiers  Canon imageCLASS 2200 Advanced Copier  17,500        5
#
#        discount    profit  shipping_cost  order_priority  year
# 29530       0.0  8399.976         349.07          Medium  2013
#
# [1 rows x 21 columns]

# %%
data[(data['shipping_cost']>=100) & (data['profit']<10)].head()
# Out:
#             order_id  order_date   ship_date       ship_mode  \
# 8      ID-2011-80230  01-03-2011  01-09-2011  Standard Class
# 257   MX-2011-146584   1/21/2011   1/27/2011  Standard Class
# 451  ES-2011-1640672  02-02-2011  02-05-2011     First Class
# 625    ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# 626    ID-2011-47575   2/15/2011   2/21/2011  Standard Class
#
#             customer_name    segment             state      country market  \
# 8            Ken Lonsdale   Consumer          Auckland  New Zealand   APAC
# 257          Hunter Lopez   Consumer           Managua    Nicaragua  LATAM
# 451            Ken Heidel  Corporate            Saxony      Germany     EU
# 625  Christopher Martinez   Consumer  National Capital  Philippines   APAC
# 626  Christopher Martinez   Consumer  National Capital  Philippines   APAC
#
#              region  ...    category sub_category  \
# 8           Oceania  ...  Technology      Copiers
# ...

# %%
df=data[data.dtypes[(data.dtypes=='float64') |(data.dtypes=='int64')].index]
df.head(3)
# Out:
#    quantity  discount   profit  shipping_cost  year  order_date_year  \
# 0         2       0.0  106.140          35.46  2011             2011
# 1         3       0.1   36.036           9.72  2011             2011
# 2         4       0.0   29.640           8.17  2011             2011
#
#    order_date_month
# 0                 1
# 1                 1
# 2                 1

# %%
data.groupby(['year']).sum()[['quantity','discount']]
# Out:
#       quantity  discount
# year
# 2011     31443  1333.394
# 2012     38111  1548.774
# 2013     48136  1935.522
# 2014     60622  2512.038

# %%
data.groupby(['year'])[['quantity','discount']].sum()
# Out:
#       quantity  discount
# year
# 2011     31443  1333.394
# 2012     38111  1548.774
# 2013     48136  1935.522
# 2014     60622  2512.038

# %%
data['sales']=data.sales.str.replace(',','').astype(int)

# %%
data.groupby(['year'])[['quantity','discount','sales']].sum()
# Out:
#       quantity  discount    sales
# year
# 2011     31443  1333.394  2259511
# 2012     38111  1548.774  2677493
# 2013     48136  1935.522  3405860
# 2014     60622  2512.038  4300041

# %% [markdown]
# ## How to remove a column,record

# %%
data.drop('order_id',axis=1).head(3)
# Out:
#    order_date   ship_date       ship_mode    customer_name   segment  \
# 0  01-01-2011  01-06-2011  Standard Class  Toby Braunhardt  Consumer
# 1  01-01-2011  01-08-2011  Standard Class      Joseph Holt  Consumer
# 2  01-01-2011  01-05-2011    Second Class    Annie Thurman  Consumer
#
#              state    country  market   region        product_id  ... sales  \
# 0      Constantine    Algeria  Africa   Africa  OFF-TEN-10000025  ...   408
# 1  New South Wales  Australia    APAC  Oceania   OFF-SU-10000618  ...   120
# 2         Budapest    Hungary    EMEA     EMEA  OFF-TEN-10001585  ...    66
#
#   quantity discount   profit  shipping_cost  order_priority  year  \
# 0        2      0.0  106.140          35.46          Medium  2011
# 1        3      0.1   36.036           9.72          Medium  2011
# 2        4      0.0   29.640           8.17            High  2011
#
#    converted_order_date order_date_year  order_date_month
# ...

# %%
data.drop(1).head(4)
# Out:
#           order_id  order_date   ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040  01-01-2011  01-06-2011  Standard Class  Toby Braunhardt
# 2     HU-2011-1220  01-01-2011  01-05-2011    Second Class    Annie Thurman
# 3  IT-2011-3647632  01-01-2011  01-05-2011    Second Class     Eugene Moren
# 4    IN-2011-47883  01-01-2011  01-08-2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... sales  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...   408
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...    66
# 3  Home Office        Stockholm     Sweden      EU    North  ...    45
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...   114
#
#   quantity discount   profit shipping_cost  order_priority  year  \
# 0        2      0.0  106.140         35.46          Medium  2011
# 2        4      0.0   29.640          8.17            High  2011
# ...

# %%
data.drop(1).reset_index().head(4)
# Out:
#    index         order_id  order_date   ship_date       ship_mode  \
# 0      0     AG-2011-2040  01-01-2011  01-06-2011  Standard Class
# 1      2     HU-2011-1220  01-01-2011  01-05-2011    Second Class
# 2      3  IT-2011-3647632  01-01-2011  01-05-2011    Second Class
# 3      4    IN-2011-47883  01-01-2011  01-08-2011  Standard Class
#
#      customer_name      segment            state    country  market  ...  \
# 0  Toby Braunhardt     Consumer      Constantine    Algeria  Africa  ...
# 1    Annie Thurman     Consumer         Budapest    Hungary    EMEA  ...
# 2     Eugene Moren  Home Office        Stockholm     Sweden      EU  ...
# 3      Joseph Holt     Consumer  New South Wales  Australia    APAC  ...
#
#   sales quantity discount   profit shipping_cost order_priority  year  \
# 0   408        2      0.0  106.140         35.46         Medium  2011
# 1    66        4      0.0   29.640          8.17           High  2011
# ...

# %%
data.drop(1).reset_index(drop=True).head(4)
# Out:
#           order_id  order_date   ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040  01-01-2011  01-06-2011  Standard Class  Toby Braunhardt
# 1     HU-2011-1220  01-01-2011  01-05-2011    Second Class    Annie Thurman
# 2  IT-2011-3647632  01-01-2011  01-05-2011    Second Class     Eugene Moren
# 3    IN-2011-47883  01-01-2011  01-08-2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... sales  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...   408
# 1     Consumer         Budapest    Hungary    EMEA     EMEA  ...    66
# 2  Home Office        Stockholm     Sweden      EU    North  ...    45
# 3     Consumer  New South Wales  Australia    APAC  Oceania  ...   114
#
#   quantity discount   profit shipping_cost  order_priority  year  \
# 0        2      0.0  106.140         35.46          Medium  2011
# 1        4      0.0   29.640          8.17            High  2011
# ...

# %% [markdown]
# # Date time functions

# %%
data['converted_order_date']=pd.to_datetime(data['order_date'])

data['order_date_year']=data['converted_order_date'].dt.year
data['order_date_month']=data['converted_order_date'].dt.month

data['converted_order_date'].dt.week
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9316\685508398.py:6: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   data['converted_order_date'].dt.week
# 0        52
# 1        52
# 2        52
# 3        52
# 4        52
#          ..
# 51285     1
# 51286     1
# 51287     1
# 51288     1
# 51289     1
# Name: converted_order_date, Length: 51290, dtype: int64
