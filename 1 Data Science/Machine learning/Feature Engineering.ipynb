# %% [markdown]
# ## `Feature Engineering`
#     1. Handling missing values (Imputation Techniques)

# %% [markdown]
# # How to handle missing values/NaN Values
# #### Sources:
#     https://www.analyticsvidhya.com/blog/2021/10/handling-missing-value/
#     https://towardsdatascience.com/feature-engineering-for-machine-learning-3a5e293a5114#3abe
#
# > **` Deleting `** : The most simple solution to the missing values is to `drop the rows or the entire column`. There is not an optimum threshold for dropping but you can use 70% as an example value and try to drop the rows and columns which have missing values with higher than this threshold.
# ![image.png](attachment:image.png)
#
# > **`  Numerical Imputation  `** :  begin with considering a possible default value of missing values in the column. For example, if you have a column that only has 1 and NA, then it is likely that the NA rows correspond to 0. The best imputation way is to use the medians of the columns. As the averages of the columns are sensitive to the outlier values, while medians are more solid in this respect.
# ![image-2.png](attachment:image-2.png)
#
# > **`  Categorical Imputation  `** : Replacing the missing values with the maximum occurred value in a column is a good option for handling categorical columns. But if you think the values in the column are distributed uniformly and there is not a dominant value, imputing a category like “Other” might be more sensible.
# ![image-3.png](attachment:image-3.png)
#
# > **` Replacing with previous value – Forward fill `** : In some cases, imputing the values with the previous value instead of mean, mode or median is more appropriate. This is called forward fill. It is mostly used in time series data.
# ![image-4.png](attachment:image-4.png)
#
# > **` Replacing with next value – Backward fill `** : In backward fill, the missing value is imputed using the next value.
# ![image-5.png](attachment:image-5.png)
#
# > **` Interpolation `** : Missing values can also be imputed using interpolation. Pandas interpolate method can be used to replace the missing values with different interpolation methods like ‘polynomial’, ‘linear’, ‘quadratic’. Default method is ‘linear’.
# ![image-6.png](attachment:image-6.png)
#
# > **` Nearest Neighbors Imputations (KNNImputer) `** :
# ![image-7.png](attachment:image-7.png)
