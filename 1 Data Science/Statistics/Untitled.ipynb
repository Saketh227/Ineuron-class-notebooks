# %% [markdown]
# # DAY 1

# %% [markdown]
# # WHAT IS STATISTICS?
#
# > Statistics is a branch of applied mathematics that involves the collection, description, analysis, and inference of conclusions from quantitative data.
#
# > Statistics is a discipline that concerns with the collection, organization, analysis, interpretation, and presentation of data.

# %% [markdown]
# # Why do we need it?
#
# * We need it to perform:
#         EDA,
#         Feature engineering, Feature selection
#         Classification and organization
#         Estimations

# %% [markdown]
# # What is Data?
# * Data is a collection of values that convey information.
#
# * Data only becomes information suitable for making decisions once it has been analyzed in some fashion.

# %% [markdown]
# # Measure of central tendency
#
# * Measure of central tendency is a single value that describes data by identifying its central position.
#
# * Central tendency seeks to characterize the distribution's central value
#
# * We use:
#         mean in absence of outliers,
#         median in presence of outliers for numerical data
#         mode for categorical data.
#
#         to define centrality of data

# %% [markdown]
# # Measure of dispersion
# * The measure of dispersion (or variability) characterizes the extent to which members of the distribution depart from its center.

# %% [markdown]
# # Descriptive vs Inferential Statistics

# %% [markdown]
# # DAY 3

# %% [markdown]
# # Gaussian/Normal Distribution/Laplace–Gauss distribution
# **Definition :**
# >Normal distribution, also known as the Gaussian distribution, is a type of continuous probability distribution (for a random variable ) that is symmetric about the mean, showing that data near the mean are more frequent in occurrence than data far from the mean.
#
# >Normal distributions are symmetrical, but not all symmetrical distributions are normal.
#
# > Skewness measures the degree of symmetry of a distribution. The normal distribution is symmetric and has a skewness of zero.
#
# > Kurtosis measures the thickness of the tail ends of a distribution in relation to the tails of a distribution. The normal distribution has a kurtosis equal to 3.0.
#
# ![image-9.png](attachment:image-9.png)
#
# * The general form of its probability density function is
# ![image.png](attachment:image.png)
#
#
# ## Q-Q Plot (used to tell wether or not a distribution is normal )

# %% [markdown]
# **`The Empirical Rule`**
# * The empirical rule, or the 68-95-99.7 rule, tells you where most of the values lie in a normal distribution:
#
# * For all normal distributions
#
# > 68.2% of the observations will appear within plus or minus one standard deviation of the mean
#
# > 95.4% of the observations will fall within +/- two standard deviations
#
# > 99.7% within +/- three standard deviations.
#
# > This means that data falling outside of three standard deviations ("3-sigma") would signify rare occurrences.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Standard Normal Distribution
#
# * The **`standard normal distribution`**, also called the **`z-distribution`**, is a **special normal distribution where the mean is 0 and the standard deviation is 1.**
#
# * Any normal distribution can be standardized by converting its values into z-scores.
#
# * **`Z-scores`** `tell you how many standard deviations from the mean each value lies`.
#
# ![image-4.png](attachment:image-4.png)
#
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)
#
# * A z-score is a standard score that tells you how many standard deviations away from the mean an individual value (x) lies:
#
#         A positive z-score means that your x-value is greater than the mean.
#         A negative z-score means that your x-value is less than the mean.
#         A z-score of zero means that your x-value is equal to the mean.
#
# * Every z-score has an associated p-value that tells you the probability of all values below or above that z-score occuring.
#
# ![image-2.png](attachment:image-2.png)
#
# # Why Do we need Standardisation?
# * emperical formula gives probability for the values that lie between +/- n standard deviations
# * Z- Score allows you to easily calculate the probability lesser/greater than certain values occurring in your distribution
#
# * To compare data sets with different means and standard deviations.
#
# * To get all the features down to a similar scale.(feature Scaling)
#
# * Find the probability that a sample mean significantly differs from a known population mean.

# %% [markdown]
# # Normalisation
# * In standardisation well the shape of the distribution does not change and most of the values lie in the interval -3 to 3.
#
# * In normalisation we Transform the values so that we get them in range between 0 and a value.
#
# * Most popular normalisation technique is Min max scaler
#
# ![image.png](attachment:image.png)
#
# * here all the values after transforming will fall in the range 0 and 1.
#
# * This is generally used in deep learning where we try to scale down all the pixels values ranging between 0 and 255 to [0,1].

# %% [markdown]
# # log Normal Distribution
# * It is right skewed.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# **`Skewness`**
# >Skewness refers to a distortion or asymmetry that deviates from the symmetrical bell curve, or normal distribution, in a set of data.
#
# > Skewness measures the degree of symmetry of a distribution. The normal distribution is symmetric and has a skewness of zero.
#
# ![image.png](attachment:image.png)
#
# If the distribution of a data set instead has a
# negative skewness (left-skewness), then the left tail of the distribution is longer than the right tail;
# positive skewness (right-skewness) implies that the right tail of the distribution is longer than the left.

# %% [markdown]
# # DAY 4

# %% [markdown]
# ## CENTRAL LIMIT THEOREM
